# %%
import pandas as pd

# %%
# %run Sioux_Falls_building_permits.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77835 entries, 0 to 17416
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          77835 non-null  object
#  1   PermitNumber  77835 non-null  object
#  2   HouseNumber   77835 non-null  object
#  3   Street        77835 non-null  object
#  4   Type          77835 non-null  object
#  5   Description   76956 non-null  object
#  6   Contractor    77794 non-null  object
#  7   Value         77835 non-null  float64
# dtypes: float64(1), object(7)
# memory usage: 3.3+ MB

# %%
allpermits.head()
# Out:
#                Date           PermitNumber HouseNumber           Street  \
# 6   12/31/2014 0:00  Permit-CB-006430-2014        4501  N NORTHVIEW AVE
# 7   12/31/2014 0:00  Permit-CB-011882-2014        1620   S SYCAMORE AVE
# 8   12/31/2014 0:00  Permit-CB-011887-2014        2307        W 57TH ST
# 9   12/31/2014 0:00  Permit-RB-011881-2014         601     W CASCADE ST
# 10  12/31/2014 0:00  Permit-RB-011883-2014        2413    E HARRIET LEA
#
#                     Type                                        Description  \
# 6    Commercial Building                    MANUFACTURING PLANT - HI-ROLLER
# 7    Commercial Building                RAZE CAR WASH AND STORAGE BUILDINGS
# 8    Commercial Building  OFFICE REMODEL; ADD 4 OFFICES; ADDING TWO DOOR...
# 9   Residential Building  MAIN FLOOR REMODEL. REMOVE AND REPLACE FIXTURE...
# 10  Residential Building  Kitchen remodel; taking 1 non bearing wall out...
#
#                      Contractor      Value
# ...

# %%
Sanford_data = allpermits[allpermits.Description.str.contains('Great Shots', case=False)]

# %%
Fleet_farm = allpermits[allpermits.Description.str.contains('fleet farm', case=False)]

# %%
bobhalla = allpermits[allpermits.Street.str.contains('BOBHALLA', case=False)]

# %%
Pentagon = allpermits[allpermits.Street.str.contains('PENTAGON', case=False)]

# %%
hercules = allpermits[allpermits.Street.str.contains('HERCULES', case=False)]

# %%
Sanford_dataFrames = [Sanford_data, Fleet_farm, bobhalla, Pentagon, hercules]

# %%
Sanford = pd.concat(Sanford_dataFrames)

# %%
sanford_sorted = Sanford.sort_values("Value", ascending = False)

# %%
sanford_sorted.head(15)
# Out:
#                   Date           PermitNumber HouseNumber           Street  \
# 7414    7/27/2018 0:00  Permit-CB-104874-2018        3035       W FLEET ST
# 468    12/12/2018 0:00  Permit-CB-117479-2018        2505      W BENSON RD
# 467    12/12/2018 0:00  Permit-CB-121397-2018        4000   N HERCULES AVE
# 7331    7/30/2018 0:00  Permit-CB-105193-2018        4021    N BOBHALLA DR
# 7415    7/27/2018 0:00  Permit-CB-104883-2018        3705  N NORTHVIEW AVE
# 1103   11/29/2017 0:00  Permit-CB-089055-2017        4225   N BOBHALLA AVE
# 1952   10/30/2018 0:00  Permit-CB-123347-2018        2505      W BENSON RD
# 4828    7/30/2015 0:00  Permit-CB-026011-2015        4024   N HERCULES AVE
# 3288    8/18/2016 0:00  Permit-CB-049175-2016        4008    N BOBHALLA DR
# 4238         9/24/2019        ZON-152244-2019        2210    W PENTAGON PL
# 11016   5/23/2018 0:00  Permit-CB-106173-2018        3035       W FLEET ST
# ...

# %%
sanford_sorted.Value.sum()
# Out:
# 40746817.0
